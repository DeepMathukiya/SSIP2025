# %%
import fiftyone as fo
import fiftyone.zoo as foz

# %%
dataset = foz.load_zoo_dataset(
              "open-images-v7",
              split="validation",
              label_types=["detections"],
              classes=["Human head"],
              max_samples=10,
          )
# Out:
# Downloading split 'validation' to 'C:\Users\dsmat\fiftyone\open-images-v7\validation' if necessary
# Downloading 'https://storage.googleapis.com/openimages/2018_04/validation/validation-images-with-rotation.csv' to 'C:\Users\dsmat\fiftyone\open-images-v7\validation\metadata\image_ids.csv'
# Downloading 'https://storage.googleapis.com/openimages/v5/class-descriptions-boxable.csv' to 'C:\Users\dsmat\fiftyone\open-images-v7\validation\metadata\classes.csv'
# Downloading 'https://storage.googleapis.com/openimages/2018_04/bbox_labels_600_hierarchy.json' to 'C:\Users\dsmat\AppData\Local\Temp\tmpyh44qrm3\metadata\hierarchy.json'
# Downloading 'https://storage.googleapis.com/openimages/v5/validation-annotations-bbox.csv' to 'C:\Users\dsmat\fiftyone\open-images-v7\validation\labels\detections.csv'
# Downloading 10 images
#  100% |█████████████████████| 10/10 [1.6m elapsed, 0s remaining, 0.1 files/s]
# Dataset info written to 'C:\Users\dsmat\fiftyone\open-images-v7\info.json'
# Loading 'open-images-v7' split 'validation'
#  100% |███████████████████| 10/10 [311.9ms elapsed, 0s remaining, 32.2 samples/s]
# Dataset 'open-images-v7-validation-10' created

# %%
session = fo.launch_app(dataset)
# session.dataset = dataset
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-72c05151-8c31-402a-a32a-8367f81a72e5 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-72c05151-8c31-402a-a32a-8367f81a72e5 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-72c05151-8c31-402a-a32a-8367f81a72e5:focus {
#   outline: none;
# }
# #fooverlay-72c05151-8c31-402a-a32a-8367f81a72e5 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-72c05151-8c31-402a-a32a-8367f81a72e5">
#    <div id="fooverlay-72c05151-8c31-402a-a32a-8367f81a72e5" style="display: none;">
#       <button id="foactivate-72c05151-8c31-402a-a32a-8367f81a72e5" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 1452px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-72c05151-8c31-402a-a32a-8367f81a72e5");
#      var overlay = document.getElementById("fooverlay-72c05151-8c31-402a-a32a-8367f81a72e5");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "72c05151-8c31-402a-a32a-8367f81a72e5" },
#               subscription: "72c05151-8c31-402a-a32a-8367f81a72e5"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>
# Welcome to
#
# ███████╗██╗███████╗████████╗██╗   ██╗ ██████╗ ███╗   ██╗███████╗
# ██╔════╝██║██╔════╝╚══██╔══╝╚██╗ ██╔╝██╔═══██╗████╗  ██║██╔════╝
# █████╗  ██║█████╗     ██║    ╚████╔╝ ██║   ██║██╔██╗ ██║█████╗
# ██╔══╝  ██║██╔══╝     ██║     ╚██╔╝  ██║   ██║██║╚██╗██║██╔══╝
# ██║     ██║██║        ██║      ██║   ╚██████╔╝██║ ╚████║███████╗
# ╚═╝     ╚═╝╚═╝        ╚═╝      ╚═╝    ╚═════╝ ╚═╝  ╚═══╝╚══════╝ v1.4.0
#
# If you're finding FiftyOne helpful, here's how you can get involved:
#
# |
# |  ⭐⭐⭐ Give the project a star on GitHub ⭐⭐⭐
# |  https://github.com/voxel51/fiftyone
# |
# |  🚀🚀🚀 Join the FiftyOne Discord community 🚀🚀🚀
# |  https://community.voxel51.com/
# |
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=ba476d81-e901-4ccf-aac9-47b7a6ee7068"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
